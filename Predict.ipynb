# %%
import pickle
import pandas as pd

with open('search_df.pkl', 'rb') as f:
    search_df = pickle.load(f)

print(f"Loaded search_df with {len(search_df)} rows")
# Out:
# Loaded search_df with 905409 rows

# %%
def search_location(user_input, limit=10):
    
    query = user_input.strip().lower()
    

    if len(query) == 0:
        return []
    

    #find the query from the search df
    mask = search_df['search_term'].str.startswith(query, na=False)
    results = search_df[mask].copy()
    
    if len(results) == 0:
        return []
    
    # deop suplicate locations with same geo id
    results = results.drop_duplicates(subset='geonameid')
    results = results.sort_values('population', ascending=False, na_position='last')
    
    output = []
    for i in range(len(results.head(limit))):
        row = results.iloc[i]
        
        if row['entity_type'] == 'state':
            entry = {
                
                'entity_type': 'state',
                'entity_name': row['entity_name'],
                'latitude':    row['latitude'],
                'longitude':   row['longitude']
            }
        
        elif row['entity_type'] == 'city':
            entry = {
                'entity_type': 'city',
                'entity_name': str(row['entity_name']) + ', ' + str(row['state']),
                'latitude':    row['latitude'],
                'longitude':   row['longitude'],
                'normalized': {
                    'geoId':     str(row['geonameid']),
                    'city':      row['city'],
                    'state':     row['state'],
                    'latitude':  row['latitude'],
                    'longitude': row['longitude']
                }
            }
        
        elif row['entity_type'] == 'pincode':
            entry = {
                'entity_type': 'pincode',
                'entity_name': row['pincode'],
                'latitude':    row['latitude'],
                'longitude':   row['longitude'],
                'normalized': {
                    'geoId':     None,
                    'city':      row['city'],
                    'state':     row['state'],
                    'pincode':   row['pincode'],
                    'latitude':  row['latitude'],
                    'longitude': row['longitude']
                }
            }
        
        output.append(entry)
    
    return output

import json
print("\n test pincode ")
print(json.dumps(search_location("6320"), indent=2, default=str))

print("\n test city")
print(json.dumps(search_location("mumb"), indent=2, default=str))

print("\n test state")
print(json.dumps(search_location("west b"), indent=2, default=str))
# Out:
#  test pincode
# [
#   {
#     "entity_type": "pincode",
#     "entity_name": "632055",
#     "latitude": 12.8123,
#     "longitude": 79.0104,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632055",
#       "latitude": 12.8123,
#       "longitude": 79.0104
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632014",
#     "latitude": 13.0318,
#     "longitude": 79.2586,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632014",
#       "latitude": 13.0318,
#       "longitude": 79.2586
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632004",
#     "latitude": 12.7779,
#     "longitude": 79.1353,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632004",
#       "latitude": 12.7779,
#       "longitude": 79.1353
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632013",
#     "latitude": 13.0318,
#     "longitude": 79.2586,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632013",
#       "latitude": 13.0318,
#       "longitude": 79.2586
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632012",
#     "latitude": 13.0318,
#     "longitude": 79.2586,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632012",
#       "latitude": 13.0318,
#       "longitude": 79.2586
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632011",
#     "latitude": 13.0318,
#     "longitude": 79.2586,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632011",
#       "latitude": 13.0318,
#       "longitude": 79.2586
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632059",
#     "latitude": 12.8123,
#     "longitude": 79.0104,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632059",
#       "latitude": 12.8123,
#       "longitude": 79.0104
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632001",
#     "latitude": 12.7779,
#     "longitude": 79.1353,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632001",
#       "latitude": 12.7779,
#       "longitude": 79.1353
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632008",
#     "latitude": 12.7779,
#     "longitude": 79.1353,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632008",
#       "latitude": 12.7779,
#       "longitude": 79.1353
#     }
#   },
#   {
#     "entity_type": "pincode",
#     "entity_name": "632006",
#     "latitude": 12.7779,
#     "longitude": 79.1353,
#     "normalized": {
#       "geoId": null,
#       "city": "Vellore",
#       "state": "Tamil Nadu",
#       "pincode": "632006",
#       "latitude": 12.7779,
#       "longitude": 79.1353
#     }
#   }
# ]
#
#  test city
# [
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbai, State of Maharashtra",
#     "latitude": 19.07283,
#     "longitude": 72.88261,
#     "normalized": {
#       "geoId": "1275339",
#       "city": "Mumbai",
#       "state": "State of Maharashtra",
#       "latitude": 19.07283,
#       "longitude": 72.88261
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Fort, State of Maharashtra",
#     "latitude": 18.93357,
#     "longitude": 72.83867,
#     "normalized": {
#       "geoId": "8030643",
#       "city": "Fort",
#       "state": "State of Maharashtra",
#       "latitude": 18.93357,
#       "longitude": 72.83867
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbarakkapatti, Mizoram",
#     "latitude": 9.91479,
#     "longitude": 78.38277,
#     "normalized": {
#       "geoId": "8442551",
#       "city": "Mumbarakkapatti",
#       "state": "Mizoram",
#       "latitude": 9.91479,
#       "longitude": 78.38277
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbar, State of Maharashtra",
#     "latitude": 19.06424,
#     "longitude": 76.93591,
#     "normalized": {
#       "geoId": "10434079",
#       "city": "Mumbar",
#       "state": "State of Maharashtra",
#       "latitude": 19.06424,
#       "longitude": 76.93591
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbar, State of Karnataka",
#     "latitude": 13.91927,
#     "longitude": 75.10673,
#     "normalized": {
#       "geoId": "10855857",
#       "city": "Mumb\u0101r",
#       "state": "State of Karnataka",
#       "latitude": 13.91927,
#       "longitude": 75.10673
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbanhalli, State of Karnataka",
#     "latitude": 13.48664,
#     "longitude": 77.92266,
#     "normalized": {
#       "geoId": "11249954",
#       "city": "Mumbanhalli",
#       "state": "State of Karnataka",
#       "latitude": 13.48664,
#       "longitude": 77.92266
#     }
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "Mumbarakkapatti, State of Tamil Nadu",
#     "latitude": 9.9127,
#     "longitude": 78.44399,
#     "normalized": {
#       "geoId": "13439312",
#       "city": "Mumbarakkapatti",
#       "state": "State of Tamil Nadu",
#       "latitude": 9.9127,
#       "longitude": 78.44399
#     }
#   }
# ]
#
#  test state
# [
#   {
#     "entity_type": "state",
#     "entity_name": "West Bengal",
#     "latitude": 24.0,
#     "longitude": 88.0
#   },
#   {
#     "entity_type": "city",
#     "entity_name": "West Bunghmun, Mizoram",
#     "latitude": 23.18024,
#     "longitude": 92.48696,
#     "normalized": {
#       "geoId": "12523348",
#       "city": "West Bunghmun",
#       "state": "Mizoram",
#       "latitude": 23.18024,
#       "longitude": 92.48696
#     }
#   }
# ]
